# %% [markdown]
# <a href="https://colab.research.google.com/github/sonhs99/NLP/blob/main/implementation/Transformer_KoChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformer 모델 구현
#
# 사용 데이터: 인공적으로 제작된 문답 쌍 11,876개 (https://github.com/songys/Chatbot_data)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

MODEL_PATH = 'drive/MyDrive/weights/Transformer/'
PREV_MODEL_NAME = 'TRv1-0'
MODEL_NAME = 'TRv1-0'

# %%
import tensorflow as tf
import numpy as np
import urllib.request
import pandas as pd

urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename="ChatBotData.csv")
train_data = pd.read_csv('ChatBotData.csv')
train_data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %% [markdown]
# ## 1. 데이터 정제 및 사전 구축

# %%
import re

# 데이터 정제
# 문장부호를 단어로부터 분리

def preprocess(sentence):
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    return sentence

questions = []
for sentence in train_data['Q']:
    questions.append(preprocess(sentence))

answers = []
for sentence in train_data['A']:
    answers.append(preprocess(sentence))

print(questions[:5])
print(answers[:5])

train_Q, train_A = questions[:-1000], answers[:-1000]
test_Q, test_A = questions[-1000:], answers[-1000:]
# Out:
# ['12시 땡 !', '1지망 학교 떨어졌어', '3박4일 놀러가고 싶다', '3박4일 정도 놀러가고 싶다', 'PPL 심하네']
# ['하루가 또 가네요 .', '위로해 드립니다 .', '여행은 언제나 좋죠 .', '여행은 언제나 좋죠 .', '눈살이 찌푸려지죠 .']

# %%
import tensorflow_datasets as tfds

# Tokenizer 선언
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13
)

# 사전 크기 조정
# 문자열에 대한 사전 크기에 시작, 종결 토큰 추가
start_token, end_token = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]
vocab_size = tokenizer.vocab_size + 2

print('시작 토큰 :', start_token)
print('종결 토큰 :', end_token)
print('사전 크기 :', vocab_size)
# Out:
# 시작 토큰 : [8178]
# 종결 토큰 : [8179]
# 사전 크기 : 8180

# %%
print('원본 :', questions[20])
tokenized_string = tokenizer.encode(questions[20])
print('부호화 문자열 :', tokenized_string)
print('복호화 :', tokenizer.decode(tokenized_string))
# Out:
# 원본 : 가스비 비싼데 감기 걸리겠어
# 부호화 문자열 : [5766, 611, 3509, 141, 685, 3747, 849]
# 복호화 : 가스비 비싼데 감기 걸리겠어

# %%
max_length = 40

def tokenize_and_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []

    for s1, s2 in zip(inputs, outputs):
        s1 = start_token + tokenizer.encode(s1) + end_token
        s2 = start_token + tokenizer.encode(s2) + end_token

        tokenized_inputs.append(s1)
        tokenized_outputs.append(s2)

    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_inputs, maxlen=max_length, padding='post'
    )
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_outputs, maxlen=max_length, padding='post'
    )

    return tokenized_inputs, tokenized_outputs

train_Q, train_A = tokenize_and_filter(train_Q, train_A)
print(train_Q, train_A)
# Out:
# [[8178 7915 4207 ...    0    0    0]
#  [8178 7971   47 ...    0    0    0]
#  [8178 7973 1435 ...    0    0    0]
#  ...
#  [8178 2537 4180 ...    0    0    0]
#  [8178 2537  166 ...    0    0    0]
#  [8178 4096   93 ...    0    0    0]] [[8178 3844   74 ...    0    0    0]
#  [8178 1830 5502 ...    0    0    0]
#  [8178 3400  777 ...    0    0    0]
#  ...
#  [8178 1413 5134 ...    0    0    0]
#  [8178 1255 2941 ...    0    0    0]
#  [8178  822 6535 ...    0    0    0]]

# %%
batch_size = 256
buffer_size = 20000

def create_dataset(questions, answers):
    dataset = tf.data.Dataset.from_tensor_slices((
        {
            'input': questions,
            'dec_inputs': answers[:, :-1] # 종결 토큰 제거, 1문장 39단어
        },
        {
            'outputs': answers[:, 1:], # 시작 토큰 제거, 1문장 39단어
        }
    ))

    dataset = dataset.cache()
    dataset = dataset.shuffle(buffer_size)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

train_dataset = create_dataset(train_Q, train_A)

# %% [markdown]
# ## 2. Custom Layer 선언

# %%
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position, dim):
        super(PositionalEncoding, self).__init__()
        self.pos_vec = self.get_vec(position, dim)

    def get_vec(self, pos, dim):
        pos_range = tf.range(pos, dtype=tf.float32)[:, tf.newaxis]
        dim_range = tf.range(dim, dtype=tf.float32)[tf.newaxis, :]
        angles = pos_range / tf.pow(10000, 2 * (dim_range // 2) / tf.cast(dim, tf.float32))

        sines = tf.math.sin(angles[:, 0::2])
        cosines = tf.math.cos(angles[:, 1::2])

        pos_vec = np.zeros(angles.shape)
        pos_vec[:, 0::2] = sines
        pos_vec[:, 1::2] = cosines

        tf_pos_vec = tf.constant(pos_vec)
        tf_pos_vec = tf_pos_vec[tf.newaxis, :]
        return tf.cast(tf_pos_vec, tf.float32)

    def call(self, x):
        # print(x.shape, self.pos_vec.shape)
        return x + self.pos_vec[:, :tf.shape(x)[1], :]

# %%
from tensorflow.keras.layers import Dense

def attention(query, key, value, mask):
    depth = tf.cast(tf.shape(key)[-1], dtype=tf.float32)
    logit = tf.matmul(query, key, transpose_b=True) / tf.math.sqrt(depth)

    if mask is not None:
        logit += (mask * -1e9)

    dist = tf.nn.softmax(logit, axis=-1)
    return tf.matmul(dist, value)

class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, num_head, dim):
        super(AttentionLayer, self).__init__()

        assert dim % num_head == 0

        self.query = Dense(dim)
        self.key = Dense(dim)
        self.value = Dense(dim)

        self.w_o = Dense(dim)

        self.num_head = num_head
        self.dim = dim
        self.head_size = dim // num_head

    def split_value(self, x, batch_size):
        split = tf.reshape(x, [batch_size, -1, self.num_head, self.head_size])  # [batch, num_vocab, num_head, head_dim]
        return tf.transpose(split, [0, 2, 1, 3])                                # [batch, num_head, num_vocab, head_dim]

    def call(self, inputs):
        query = self.query(inputs[0])
        key = self.key(inputs[1])
        value = self.value(inputs[2])
        mask = inputs[3]

        batch_size = tf.shape(query)[0]

        query = self.split_value(query, batch_size)
        key = self.split_value(key, batch_size)
        value = self.split_value(value, batch_size)

        attention_value = attention(query, key, value, mask)                # [batch, num_head, num_vocab, head_dim]
        attention_value = tf.transpose(attention_value, perm=[0, 2, 1, 3])  # [batch, num_vocab, num_head, head_dim]
        attention_value = tf.reshape(attention_value, [batch_size, -1, self.dim]) # [batch, num_vocab, d_model] (num_head * head_dim = d_model)
        return self.w_o(attention_value)

# %% [markdown]
# ## 3. Encoder-Decoder 블록 및 Transformer 모델 생성

# %%
def encoder_block(dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None, dim])
    padding_input = tf.keras.layers.Input([1, 1, None])

    attention_x = AttentionLayer(num_head, dim)([input, input, input, padding_input])
    attention_x = tf.keras.layers.Dropout(dropout)(attention_x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(input + attention_x)

    ffnn_x = Dense(dif, activation='relu')(x)
    ffnn_x = Dense(dim)(ffnn_x)

    ffnn_x = tf.keras.layers.Dropout(dropout)(ffnn_x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + ffnn_x)
    return tf.keras.Model(inputs=[input, padding_input], outputs=x)

def encoder(vocab_size, num_layers, dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None,])
    padding_input = tf.keras.layers.Input([1, 1, None])

    embedding = tf.keras.layers.Embedding(vocab_size, dim)(input)
    embedding *= tf.math.sqrt(tf.cast(dim, dtype=tf.float32)) # Embedding Vector가 작게 학습되는 것을 방지
    positional_encoding = PositionalEncoding(vocab_size, dim)(embedding)
    output = tf.keras.layers.Dropout(dropout)(positional_encoding)

    for i in range(num_layers):
        output = encoder_block(dif, num_head, dim, dropout)([output, padding_input])

    return tf.keras.Model(inputs=[input, padding_input], outputs=output, name='encoder')

# %%
def decoder_block(dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None, dim])
    encoder_input = tf.keras.layers.Input([None, dim])
    padding_input = tf.keras.layers.Input([1, 1, None])
    mask_input = tf.keras.layers.Input([1, None, None])

    mask_attention_x = AttentionLayer(num_head, dim)([input, input, input, mask_input])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(input + mask_attention_x)

    attention_x = AttentionLayer(num_head, dim)([x, encoder_input, encoder_input, padding_input])
    attention_x = tf.keras.layers.Dropout(dropout)(attention_x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + attention_x)

    ffnn_x = Dense(dif, activation='relu')(x)
    ffnn_x = Dense(dim)(ffnn_x)

    ffnn_x = tf.keras.layers.Dropout(dropout)(ffnn_x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + ffnn_x)
    return tf.keras.Model(inputs=[input, encoder_input, padding_input, mask_input], outputs=x)

def decoder(vocab_size, num_layers, dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None,])
    encoder_input = tf.keras.layers.Input([None, dim])
    padding_input = tf.keras.layers.Input([1, 1, None])
    mask_input = tf.keras.layers.Input([1, None, None])

    embedding = tf.keras.layers.Embedding(vocab_size, dim)(input)
    embedding *= tf.math.sqrt(tf.cast(dim, dtype=tf.float32)) # ?
    positional_encoding = PositionalEncoding(vocab_size, dim)(embedding)
    output = tf.keras.layers.Dropout(dropout)(positional_encoding)

    for i in range(num_layers):
        output = decoder_block(dif, num_head, dim, dropout)([output, encoder_input, padding_input, mask_input])

    return tf.keras.Model(inputs=[input, encoder_input, padding_input, mask_input], outputs=output, name='decoder')

# %%
def padding_mask(x):
    mask = tf.cast(tf.math.equal(x, 0), dtype=tf.float32)
    return mask[:, tf.newaxis, tf.newaxis, :]

def look_ahead_mask(x):
    seq_len = tf.shape(x)[1]
    t_look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
    t_padding_mask = padding_mask(x)
    return tf.maximum(t_look_ahead_mask, t_padding_mask)

def transformer(vocab_size, num_layers, dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None,], name='input')
    dec_input = tf.keras.layers.Input([None,], name='dec_inputs')

    enc_padding = tf.keras.layers.Lambda(padding_mask, output_shape=[1, 1, None])(input)
    dec_padding = tf.keras.layers.Lambda(padding_mask, output_shape=[1, 1, None])(input)

    dec_mask = tf.keras.layers.Lambda(look_ahead_mask, output_shape=[1, None, None])(dec_input)

    enc = encoder(vocab_size, num_layers, dif, num_head, dim, dropout)([input, enc_padding])
    dec = decoder(vocab_size, num_layers, dif, num_head, dim, dropout)([dec_input, enc, dec_padding, dec_mask])

    output = tf.keras.layers.Dense(vocab_size, name='outputs')(dec)
    return tf.keras.Model(inputs=[input, dec_input], outputs=output)

# %%
dim = 512
num_layers = 6
num_head = 8
diff = 2048
dropout = 0.1

model = transformer(
    vocab_size=vocab_size,
    num_layers=num_layers,
    dif=diff,
    dim=dim,
    num_head=num_head,
    dropout=dropout
)

if PREV_MODEL_NAME: model.load_weights(MODEL_PATH+PREV_MODEL_NAME+'.h5')

# %% [markdown]
# ## 4. 모델 Compile 및 학습

# %%
class TransformerSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, dim, warmup_step=4000):
        self.d_model = tf.cast(dim, tf.float32)
        self.warmup_step = warmup_step

    def __call__(self, step):
        step = step
        step = tf.cast(step, tf.float32)
        temp1 = tf.math.rsqrt(step)
        temp2 = step * (self.warmup_step ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(temp1, temp2)

    def get_config(self):
        config = {
            'dim': self.d_model,
            'warmup_step': self.warmup_step,
        }
        return config

# %%
lr = TransformerSchedule(dim)
opt = tf.optimizers.Adam(lr, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, max_length - 1))
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

def loss_function(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, max_length - 1))
    loss = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True, reduction='none'
    )(y_true, y_pred)
    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
    loss = tf.multiply(loss, mask)
    return tf.reduce_mean(loss)

model.compile(
    optimizer=opt, loss=loss_function, metrics=[accuracy])

# %%
model.summary(expand_nested=True)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, None)]               0         []
#
#  dec_inputs (InputLayer)     [(None, None)]               0         []
#
#  lambda (Lambda)             (None, 1, 1, None)           0         ['input[0][0]']
#
#  encoder (Functional)        (None, None, 512)            2310246   ['input[0][0]',
#                                                           4          'lambda[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)       [(None, None)]               0         []                           |
# |                                                                                                |
# | embedding (Embedding)      (None, None, 512)            4188160   []                           |
# |                                                                                                |
# | tf.math.multiply (TFOpLam  (None, None, 512)            0         []                           |
# | bda)                                                                                           |
# |                                                                                                |
# | positional_encoding (Posi  (None, None, 512)            0         []                           |
# | tionalEncoding)                                                                                |
# |                                                                                                |
# | dropout (Dropout)          (None, None, 512)            0         []                           |
# |                                                                                                |
# | input_2 (InputLayer)       [(None, 1, 1, None)]         0         []                           |
# |                                                                                                |
# | model (Functional)         (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_3 (InputLayer)      [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_4 (InputLayer)      [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer (Attenti  (None, None, 512)            1050624   []                          ||
# || onLayer)                                                                                     ||
# ||                                                                                              ||
# || dropout_1 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add (TF  (None, None, 512)            0         []                          ||
# || OpLambda)                                                                                    ||
# ||                                                                                              ||
# || layer_normalization (Lay  (None, None, 512)            1024      []                          ||
# || erNormalization)                                                                             ||
# ||                                                                                              ||
# || dense_4 (Dense)           (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_5 (Dense)           (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_2 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_1 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_1 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_1 (Functional)       (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_5 (InputLayer)      [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_6 (InputLayer)      [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_1 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_3 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_2 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_2 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_10 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_11 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_4 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_3 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_3 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_2 (Functional)       (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_7 (InputLayer)      [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_8 (InputLayer)      [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_2 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_5 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_4 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_4 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_16 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_17 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_6 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_5 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_5 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_3 (Functional)       (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_9 (InputLayer)      [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_10 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_3 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_7 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_6 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_6 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_22 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_23 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_8 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_7 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_7 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_4 (Functional)       (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_11 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_12 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_4 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_9 (Dropout)       (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_8 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_8 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_28 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_29 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_10 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_9 (  (None, None, 512)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_9 (L  (None, None, 512)            1024      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_5 (Functional)       (None, None, 512)            3152384   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_13 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_14 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_5 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_11 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_10   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_10 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_34 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_35 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_12 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_11   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_11 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  lambda_1 (Lambda)           (None, 1, 1, None)           0         ['input[0][0]']
#
#  lambda_2 (Lambda)           (None, 1, None, None)        0         ['dec_inputs[0][0]']
#
#  decoder (Functional)        (None, None, 512)            2941235   ['dec_inputs[0][0]',
#                                                           2          'encoder[0][0]',
#                                                                      'lambda_1[0][0]',
#                                                                      'lambda_2[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_15 (InputLayer)      [(None, None)]               0         []                           |
# |                                                                                                |
# | embedding_1 (Embedding)    (None, None, 512)            4188160   []                           |
# |                                                                                                |
# | tf.math.multiply_1 (TFOpL  (None, None, 512)            0         []                           |
# | ambda)                                                                                         |
# |                                                                                                |
# | positional_encoding_1 (Po  (None, None, 512)            0         []                           |
# | sitionalEncoding)                                                                              |
# |                                                                                                |
# | dropout_13 (Dropout)       (None, None, 512)            0         []                           |
# |                                                                                                |
# | input_16 (InputLayer)      [(None, None, 512)]          0         []                           |
# |                                                                                                |
# | input_17 (InputLayer)      [(None, 1, 1, None)]         0         []                           |
# |                                                                                                |
# | input_18 (InputLayer)      [(None, 1, None, None)]      0         []                           |
# |                                                                                                |
# | model_6 (Functional)       (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_19 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_22 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_6 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_12   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_12 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_20 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_21 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_7 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_14 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_13   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_13 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_44 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_45 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_15 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_14   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_14 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_7 (Functional)       (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_23 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_26 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_8 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_15   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_15 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_24 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_25 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_9 (Atten  (None, None, 512)            1050624   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || dropout_16 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_16   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_16 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_54 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_55 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_17 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_17   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_17 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_8 (Functional)       (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_27 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_30 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_10 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_18   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_18 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_28 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_29 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_11 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || dropout_18 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_19   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_19 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_64 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_65 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_19 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_20   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_20 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_9 (Functional)       (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_31 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_34 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_12 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_21   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_21 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_32 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_33 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_13 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || dropout_20 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_22   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_22 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_74 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_75 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_21 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_23   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_23 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_10 (Functional)      (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_35 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_38 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_14 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_24   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_24 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_36 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_37 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_15 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || dropout_22 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_25   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_25 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_84 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_85 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_23 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_26   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_26 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_11 (Functional)      (None, None, 512)            4204032   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_39 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_42 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_16 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_27   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_27 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || input_40 (InputLayer)     [(None, None, 512)]          0         []                          ||
# ||                                                                                              ||
# || input_41 (InputLayer)     [(None, 1, 1, None)]         0         []                          ||
# ||                                                                                              ||
# || attention_layer_17 (Atte  (None, None, 512)            1050624   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || dropout_24 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_28   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_28 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_94 (Dense)          (None, None, 2048)           1050624   []                          ||
# ||                                                                                              ||
# || dense_95 (Dense)          (None, None, 512)            1049088   []                          ||
# ||                                                                                              ||
# || dropout_25 (Dropout)      (None, None, 512)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_29   (None, None, 512)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_29 (  (None, None, 512)            1024      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  outputs (Dense)             (None, None, 8180)           4196340   ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 56711156 (216.34 MB)
# Trainable params: 56711156 (216.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
epoch = 1000
history = model.fit(train_dataset, epochs=epoch)
# Out:
# Epoch 1/1000
# 43/43 [==============================] - 74s 426ms/step - loss: 1.0927 - accuracy: 0.0254
# Epoch 2/1000
# 43/43 [==============================] - 17s 405ms/step - loss: 1.0922 - accuracy: 0.0255
# Epoch 3/1000
# 43/43 [==============================] - 17s 394ms/step - loss: 1.0913 - accuracy: 0.0252
# Epoch 4/1000
# 43/43 [==============================] - 18s 411ms/step - loss: 1.0903 - accuracy: 0.0256
# Epoch 5/1000
# 43/43 [==============================] - 17s 386ms/step - loss: 1.0804 - accuracy: 0.0277
# Epoch 6/1000
# 43/43 [==============================] - 17s 384ms/step - loss: 1.0259 - accuracy: 0.0477
# Epoch 7/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 0.9972 - accuracy: 0.0496
# Epoch 8/1000
# 43/43 [==============================] - 16s 381ms/step - loss: 0.9734 - accuracy: 0.0503
# Epoch 9/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 0.9514 - accuracy: 0.0509
# Epoch 10/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.9308 - accuracy: 0.0518
# Epoch 11/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.9153 - accuracy: 0.0529
# Epoch 12/1000
# 43/43 [==============================] - 17s 387ms/step - loss: 0.9024 - accuracy: 0.0535
# Epoch 13/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.8892 - accuracy: 0.0542
# Epoch 14/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.8756 - accuracy: 0.0552
# Epoch 15/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.8583 - accuracy: 0.0564
# Epoch 16/1000
# 43/43 [==============================] - 16s 381ms/step - loss: 0.8401 - accuracy: 0.0576
# Epoch 17/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.8186 - accuracy: 0.0588
# Epoch 18/1000
# 43/43 [==============================] - 17s 386ms/step - loss: 0.7950 - accuracy: 0.0606
# Epoch 19/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.7693 - accuracy: 0.0626
# Epoch 20/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.7421 - accuracy: 0.0649
# Epoch 21/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.7133 - accuracy: 0.0677
# Epoch 22/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.6808 - accuracy: 0.0714
# Epoch 23/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.6514 - accuracy: 0.0747
# Epoch 24/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.6191 - accuracy: 0.0790
# Epoch 25/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.5876 - accuracy: 0.0829
# Epoch 26/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.5541 - accuracy: 0.0875
# Epoch 27/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.5218 - accuracy: 0.0920
# Epoch 28/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.4914 - accuracy: 0.0961
# Epoch 29/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.4600 - accuracy: 0.1006
# Epoch 30/1000
# 43/43 [==============================] - 16s 381ms/step - loss: 0.4299 - accuracy: 0.1050
# Epoch 31/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.4026 - accuracy: 0.1089
# Epoch 32/1000
# 43/43 [==============================] - 17s 384ms/step - loss: 0.3734 - accuracy: 0.1130
# Epoch 33/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.3486 - accuracy: 0.1164
# Epoch 34/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.3248 - accuracy: 0.1197
# Epoch 35/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.3037 - accuracy: 0.1223
# Epoch 36/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.2856 - accuracy: 0.1244
# Epoch 37/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.2690 - accuracy: 0.1267
# Epoch 38/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.2545 - accuracy: 0.1285
# Epoch 39/1000
# 43/43 [==============================] - 16s 381ms/step - loss: 0.2408 - accuracy: 0.1300
# Epoch 40/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.2286 - accuracy: 0.1316
# Epoch 41/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.2174 - accuracy: 0.1329
# Epoch 42/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.2073 - accuracy: 0.1338
# Epoch 43/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.1985 - accuracy: 0.1349
# Epoch 44/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.1910 - accuracy: 0.1353
# Epoch 45/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.1837 - accuracy: 0.1362
# Epoch 46/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.1772 - accuracy: 0.1371
# Epoch 47/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.1690 - accuracy: 0.1378
# Epoch 48/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.1640 - accuracy: 0.1384
# Epoch 49/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.1560 - accuracy: 0.1395
# Epoch 50/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.1501 - accuracy: 0.1402
# Epoch 51/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.1469 - accuracy: 0.1407
# Epoch 52/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.1385 - accuracy: 0.1418
# Epoch 53/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.1321 - accuracy: 0.1429
# Epoch 54/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.1260 - accuracy: 0.1439
# Epoch 55/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.1185 - accuracy: 0.1454
# Epoch 56/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.1126 - accuracy: 0.1463
# Epoch 57/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.1049 - accuracy: 0.1480
# Epoch 58/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0998 - accuracy: 0.1489
# Epoch 59/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0920 - accuracy: 0.1507
# Epoch 60/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0856 - accuracy: 0.1522
# Epoch 61/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0784 - accuracy: 0.1540
# Epoch 62/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0716 - accuracy: 0.1556
# Epoch 63/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0660 - accuracy: 0.1569
# Epoch 64/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0612 - accuracy: 0.1580
# Epoch 65/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0555 - accuracy: 0.1597
# Epoch 66/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0517 - accuracy: 0.1607
# Epoch 67/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0490 - accuracy: 0.1611
# Epoch 68/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0448 - accuracy: 0.1621
# Epoch 69/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0409 - accuracy: 0.1631
# Epoch 70/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0387 - accuracy: 0.1637
# Epoch 71/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0365 - accuracy: 0.1641
# Epoch 72/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0370 - accuracy: 0.1642
# Epoch 73/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0335 - accuracy: 0.1648
# Epoch 74/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0335 - accuracy: 0.1648
# Epoch 75/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0301 - accuracy: 0.1656
# Epoch 76/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0302 - accuracy: 0.1654
# Epoch 77/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0311 - accuracy: 0.1652
# Epoch 78/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0293 - accuracy: 0.1656
# Epoch 79/1000
# 43/43 [==============================] - 16s 370ms/step - loss: 0.0267 - accuracy: 0.1663
# Epoch 80/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0282 - accuracy: 0.1659
# Epoch 81/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0279 - accuracy: 0.1658
# Epoch 82/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0274 - accuracy: 0.1659
# Epoch 83/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0272 - accuracy: 0.1661
# Epoch 84/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0262 - accuracy: 0.1663
# Epoch 85/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0253 - accuracy: 0.1664
# Epoch 86/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0272 - accuracy: 0.1660
# Epoch 87/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0260 - accuracy: 0.1663
# Epoch 88/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0269 - accuracy: 0.1660
# Epoch 89/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0241 - accuracy: 0.1668
# Epoch 90/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0238 - accuracy: 0.1668
# Epoch 91/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0263 - accuracy: 0.1660
# Epoch 92/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0253 - accuracy: 0.1665
# Epoch 93/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0241 - accuracy: 0.1667
# Epoch 94/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0255 - accuracy: 0.1662
# Epoch 95/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0237 - accuracy: 0.1667
# Epoch 96/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0229 - accuracy: 0.1670
# Epoch 97/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0224 - accuracy: 0.1671
# Epoch 98/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0211 - accuracy: 0.1674
# Epoch 99/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0216 - accuracy: 0.1673
# Epoch 100/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0213 - accuracy: 0.1674
# Epoch 101/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0194 - accuracy: 0.1680
# Epoch 102/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0194 - accuracy: 0.1680
# Epoch 103/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0184 - accuracy: 0.1681
# Epoch 104/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0167 - accuracy: 0.1686
# Epoch 105/1000
# 43/43 [==============================] - 17s 384ms/step - loss: 0.0169 - accuracy: 0.1687
# Epoch 106/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0177 - accuracy: 0.1685
# Epoch 107/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0167 - accuracy: 0.1687
# Epoch 108/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0186 - accuracy: 0.1681
# Epoch 109/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0154 - accuracy: 0.1691
# Epoch 110/1000
# 43/43 [==============================] - 16s 370ms/step - loss: 0.0150 - accuracy: 0.1691
# Epoch 111/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0155 - accuracy: 0.1691
# Epoch 112/1000
# 43/43 [==============================] - 16s 370ms/step - loss: 0.0150 - accuracy: 0.1691
# Epoch 113/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0140 - accuracy: 0.1695
# Epoch 114/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0136 - accuracy: 0.1696
# Epoch 115/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0136 - accuracy: 0.1695
# Epoch 116/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0135 - accuracy: 0.1697
# Epoch 117/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0134 - accuracy: 0.1696
# Epoch 118/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0128 - accuracy: 0.1698
# Epoch 119/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0128 - accuracy: 0.1698
# Epoch 120/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0122 - accuracy: 0.1700
# Epoch 121/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0124 - accuracy: 0.1698
# Epoch 122/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0117 - accuracy: 0.1702
# Epoch 123/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0135 - accuracy: 0.1696
# Epoch 124/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0115 - accuracy: 0.1701
# Epoch 125/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0111 - accuracy: 0.1703
# Epoch 126/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0115 - accuracy: 0.1701
# Epoch 127/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0115 - accuracy: 0.1702
# Epoch 128/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0099 - accuracy: 0.1705
# Epoch 129/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0097 - accuracy: 0.1706
# Epoch 130/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0105 - accuracy: 0.1704
# Epoch 131/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0106 - accuracy: 0.1704
# Epoch 132/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0101 - accuracy: 0.1705
# Epoch 133/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0102 - accuracy: 0.1705
# Epoch 134/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0103 - accuracy: 0.1704
# Epoch 135/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0093 - accuracy: 0.1707
# Epoch 136/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0091 - accuracy: 0.1707
# Epoch 137/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0093 - accuracy: 0.1708
# Epoch 138/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0091 - accuracy: 0.1708
# Epoch 139/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0091 - accuracy: 0.1707
# Epoch 140/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0091 - accuracy: 0.1709
# Epoch 141/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0089 - accuracy: 0.1708
# Epoch 142/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0165 - accuracy: 0.1691
# Epoch 143/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0073 - accuracy: 0.1712
# Epoch 144/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0066 - accuracy: 0.1715
# Epoch 145/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0076 - accuracy: 0.1712
# Epoch 146/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0070 - accuracy: 0.1714
# Epoch 147/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0082 - accuracy: 0.1710
# Epoch 148/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0087 - accuracy: 0.1709
# Epoch 149/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0081 - accuracy: 0.1710
# Epoch 150/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0074 - accuracy: 0.1712
# Epoch 151/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0081 - accuracy: 0.1710
# Epoch 152/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0085 - accuracy: 0.1711
# Epoch 153/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0080 - accuracy: 0.1710
# Epoch 154/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0077 - accuracy: 0.1712
# Epoch 155/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0071 - accuracy: 0.1714
# Epoch 156/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0067 - accuracy: 0.1715
# Epoch 157/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0073 - accuracy: 0.1713
# Epoch 158/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0073 - accuracy: 0.1713
# Epoch 159/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0070 - accuracy: 0.1713
# Epoch 160/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0067 - accuracy: 0.1714
# Epoch 161/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0072 - accuracy: 0.1713
# Epoch 162/1000
# 43/43 [==============================] - 17s 383ms/step - loss: 0.0064 - accuracy: 0.1714
# Epoch 163/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0067 - accuracy: 0.1714
# Epoch 164/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0074 - accuracy: 0.1712
# Epoch 165/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0066 - accuracy: 0.1714
# Epoch 166/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0064 - accuracy: 0.1714
# Epoch 167/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0064 - accuracy: 0.1715
# Epoch 168/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0057 - accuracy: 0.1718
# Epoch 169/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0070 - accuracy: 0.1713
# Epoch 170/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0061 - accuracy: 0.1716
# Epoch 171/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0059 - accuracy: 0.1716
# Epoch 172/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0059 - accuracy: 0.1716
# Epoch 173/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0060 - accuracy: 0.1716
# Epoch 174/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0059 - accuracy: 0.1716
# Epoch 175/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0061 - accuracy: 0.1716
# Epoch 176/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0055 - accuracy: 0.1718
# Epoch 177/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0056 - accuracy: 0.1717
# Epoch 178/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0050 - accuracy: 0.1719
# Epoch 179/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0062 - accuracy: 0.1715
# Epoch 180/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0061 - accuracy: 0.1716
# Epoch 181/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0049 - accuracy: 0.1719
# Epoch 182/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0054 - accuracy: 0.1718
# Epoch 183/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0055 - accuracy: 0.1717
# Epoch 184/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0057 - accuracy: 0.1717
# Epoch 185/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0055 - accuracy: 0.1717
# Epoch 186/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0054 - accuracy: 0.1718
# Epoch 187/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0055 - accuracy: 0.1718
# Epoch 188/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0052 - accuracy: 0.1719
# Epoch 189/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0049 - accuracy: 0.1719
# Epoch 190/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0049 - accuracy: 0.1719
# Epoch 191/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0054 - accuracy: 0.1718
# Epoch 192/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0055 - accuracy: 0.1717
# Epoch 193/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0050 - accuracy: 0.1719
# Epoch 194/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0045 - accuracy: 0.1720
# Epoch 195/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0047 - accuracy: 0.1720
# Epoch 196/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0045 - accuracy: 0.1720
# Epoch 197/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0048 - accuracy: 0.1720
# Epoch 198/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0055 - accuracy: 0.1717
# Epoch 199/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0050 - accuracy: 0.1719
# Epoch 200/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0047 - accuracy: 0.1720
# Epoch 201/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0046 - accuracy: 0.1720
# Epoch 202/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0039 - accuracy: 0.1721
# Epoch 203/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0042 - accuracy: 0.1721
# Epoch 204/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0044 - accuracy: 0.1721
# Epoch 205/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0046 - accuracy: 0.1720
# Epoch 206/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0042 - accuracy: 0.1721
# Epoch 207/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0042 - accuracy: 0.1720
# Epoch 208/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0044 - accuracy: 0.1720
# Epoch 209/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0048 - accuracy: 0.1719
# Epoch 210/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0044 - accuracy: 0.1721
# Epoch 211/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0040 - accuracy: 0.1722
# Epoch 212/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0044 - accuracy: 0.1721
# Epoch 213/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0044 - accuracy: 0.1720
# Epoch 214/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0040 - accuracy: 0.1722
# Epoch 215/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0041 - accuracy: 0.1721
# Epoch 216/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0038 - accuracy: 0.1722
# Epoch 217/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0040 - accuracy: 0.1721
# Epoch 218/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0043 - accuracy: 0.1721
# Epoch 219/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0038 - accuracy: 0.1721
# Epoch 220/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0037 - accuracy: 0.1722
# Epoch 221/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0041 - accuracy: 0.1721
# Epoch 222/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0039 - accuracy: 0.1722
# Epoch 223/1000
# 43/43 [==============================] - 16s 370ms/step - loss: 0.0035 - accuracy: 0.1723
# Epoch 224/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 225/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0040 - accuracy: 0.1721
# Epoch 226/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0043 - accuracy: 0.1721
# Epoch 227/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0044 - accuracy: 0.1720
# Epoch 228/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0038 - accuracy: 0.1722
# Epoch 229/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0038 - accuracy: 0.1723
# Epoch 230/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0035 - accuracy: 0.1722
# Epoch 231/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0038 - accuracy: 0.1722
# Epoch 232/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0039 - accuracy: 0.1722
# Epoch 233/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0043 - accuracy: 0.1722
# Epoch 234/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0031 - accuracy: 0.1723
# Epoch 235/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0032 - accuracy: 0.1724
# Epoch 236/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0036 - accuracy: 0.1723
# Epoch 237/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0035 - accuracy: 0.1723
# Epoch 238/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0054 - accuracy: 0.1720
# Epoch 239/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0035 - accuracy: 0.1722
# Epoch 240/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 241/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 242/1000
# 43/43 [==============================] - 18s 424ms/step - loss: 0.0035 - accuracy: 0.1723
# Epoch 243/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0034 - accuracy: 0.1723
# Epoch 244/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0034 - accuracy: 0.1723
# Epoch 245/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0031 - accuracy: 0.1724
# Epoch 246/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0032 - accuracy: 0.1724
# Epoch 247/1000
# 43/43 [==============================] - 16s 381ms/step - loss: 0.0036 - accuracy: 0.1723
# Epoch 248/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0036 - accuracy: 0.1722
# Epoch 249/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 250/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 251/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0035 - accuracy: 0.1723
# Epoch 252/1000
# 43/43 [==============================] - 17s 386ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 253/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 254/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 255/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0036 - accuracy: 0.1723
# Epoch 256/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0039 - accuracy: 0.1722
# Epoch 257/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 258/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0034 - accuracy: 0.1723
# Epoch 259/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 260/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 261/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 262/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 263/1000
# 43/43 [==============================] - 16s 371ms/step - loss: 0.0033 - accuracy: 0.1723
# Epoch 264/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 265/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 266/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0032 - accuracy: 0.1723
# Epoch 267/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0029 - accuracy: 0.1725
# Epoch 268/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0032 - accuracy: 0.1723
# Epoch 269/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 270/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 271/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 272/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 273/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 274/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 275/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 276/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 277/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 278/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0029 - accuracy: 0.1725
# Epoch 279/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0028 - accuracy: 0.1725
# Epoch 280/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 281/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0025 - accuracy: 0.1725
# Epoch 282/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 283/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0030 - accuracy: 0.1724
# Epoch 284/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 285/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 286/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 287/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 288/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0028 - accuracy: 0.1724
# Epoch 289/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 290/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 291/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 292/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0025 - accuracy: 0.1725
# Epoch 293/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 294/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 295/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0024 - accuracy: 0.1726
# Epoch 296/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 297/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 298/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0025 - accuracy: 0.1726
# Epoch 299/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 300/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 301/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 302/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 303/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0024 - accuracy: 0.1726
# Epoch 304/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 305/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 306/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0025 - accuracy: 0.1726
# Epoch 307/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0035 - accuracy: 0.1723
# Epoch 308/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 309/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 310/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0026 - accuracy: 0.1725
# Epoch 311/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0023 - accuracy: 0.1725
# Epoch 312/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0024 - accuracy: 0.1726
# Epoch 313/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 314/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0024 - accuracy: 0.1726
# Epoch 315/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 316/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 317/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 318/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0029 - accuracy: 0.1724
# Epoch 319/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0025 - accuracy: 0.1725
# Epoch 320/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 321/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0024 - accuracy: 0.1726
# Epoch 322/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 323/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 324/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0021 - accuracy: 0.1727
# Epoch 325/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0020 - accuracy: 0.1727
# Epoch 326/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 327/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 328/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 329/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 330/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 331/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 332/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0025 - accuracy: 0.1726
# Epoch 333/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 334/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0019 - accuracy: 0.1726
# Epoch 335/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 336/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 337/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 338/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 339/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 340/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 341/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 342/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 343/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0027 - accuracy: 0.1725
# Epoch 344/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0024 - accuracy: 0.1725
# Epoch 345/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 346/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 347/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 348/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 349/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 350/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 351/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 352/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 353/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0023 - accuracy: 0.1726
# Epoch 354/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 355/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 356/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0020 - accuracy: 0.1727
# Epoch 357/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 358/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0020 - accuracy: 0.1727
# Epoch 359/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0020 - accuracy: 0.1727
# Epoch 360/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0019 - accuracy: 0.1726
# Epoch 361/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 362/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 363/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0019 - accuracy: 0.1726
# Epoch 364/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 365/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 366/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0020 - accuracy: 0.1727
# Epoch 367/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 368/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0020 - accuracy: 0.1726
# Epoch 369/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 370/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 371/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 372/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0019 - accuracy: 0.1726
# Epoch 373/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0021 - accuracy: 0.1726
# Epoch 374/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 375/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 376/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 377/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 378/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0025 - accuracy: 0.1725
# Epoch 379/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0026 - accuracy: 0.1726
# Epoch 380/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 381/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 382/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 383/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 384/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 385/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 386/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 387/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 388/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 389/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 390/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 391/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 392/1000
# 43/43 [==============================] - 16s 372ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 393/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 394/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 395/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 396/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 397/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 398/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 399/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 400/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 401/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 402/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 403/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 404/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 405/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 406/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 407/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 408/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 409/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0019 - accuracy: 0.1727
# Epoch 410/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0028 - accuracy: 0.1725
# Epoch 411/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 412/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 413/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 414/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 415/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 416/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 417/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1727
# Epoch 418/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 419/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 420/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 421/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 422/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 423/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 424/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 425/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 426/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 427/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1728
# Epoch 428/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 429/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 430/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 431/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 432/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0031 - accuracy: 0.1726
# Epoch 433/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0022 - accuracy: 0.1726
# Epoch 434/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 435/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 436/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0018 - accuracy: 0.1727
# Epoch 437/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 438/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 439/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 440/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0015 - accuracy: 0.1727
# Epoch 441/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 442/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 443/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 444/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 445/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 446/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0016 - accuracy: 0.1728
# Epoch 447/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0014 - accuracy: 0.1727
# Epoch 448/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 449/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 450/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 451/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0014 - accuracy: 0.1727
# Epoch 452/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0014 - accuracy: 0.1728
# Epoch 453/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0016 - accuracy: 0.1727
# Epoch 454/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 455/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 456/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 457/1000
# 43/43 [==============================] - 16s 373ms/step - loss: 0.0013 - accuracy: 0.1728
# Epoch 458/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 0.0017 - accuracy: 0.1727
# Epoch 459/1000
# ...
# 43/43 [==============================] - 16s 380ms/step - loss: 9.3999e-04 - accuracy: 0.1729
# Epoch 855/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.4914e-04 - accuracy: 0.1729
# Epoch 856/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.0081e-04 - accuracy: 0.1729
# Epoch 857/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 7.8639e-04 - accuracy: 0.1729
# Epoch 858/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.8025e-04 - accuracy: 0.1729
# Epoch 859/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 9.6660e-04 - accuracy: 0.1729
# Epoch 860/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 9.6621e-04 - accuracy: 0.1729
# Epoch 861/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 9.1797e-04 - accuracy: 0.1729
# Epoch 862/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 8.5559e-04 - accuracy: 0.1729
# Epoch 863/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 6.8904e-04 - accuracy: 0.1729
# Epoch 864/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.0775e-04 - accuracy: 0.1729
# Epoch 865/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.0427e-04 - accuracy: 0.1729
# Epoch 866/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 7.5804e-04 - accuracy: 0.1729
# Epoch 867/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 9.9387e-04 - accuracy: 0.1729
# Epoch 868/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 8.2801e-04 - accuracy: 0.1729
# Epoch 869/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 6.8886e-04 - accuracy: 0.1729
# Epoch 870/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 8.1739e-04 - accuracy: 0.1729
# Epoch 871/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.7449e-04 - accuracy: 0.1729
# Epoch 872/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.6146e-04 - accuracy: 0.1729
# Epoch 873/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.8076e-04 - accuracy: 0.1729
# Epoch 874/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 9.1773e-04 - accuracy: 0.1729
# Epoch 875/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 9.2260e-04 - accuracy: 0.1729
# Epoch 876/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 8.5136e-04 - accuracy: 0.1729
# Epoch 877/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.7262e-04 - accuracy: 0.1729
# Epoch 878/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 8.4594e-04 - accuracy: 0.1729
# Epoch 879/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 9.5272e-04 - accuracy: 0.1728
# Epoch 880/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 8.1768e-04 - accuracy: 0.1728
# Epoch 881/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.4886e-04 - accuracy: 0.1728
# Epoch 882/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.7658e-04 - accuracy: 0.1729
# Epoch 883/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.8214e-04 - accuracy: 0.1729
# Epoch 884/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.9667e-04 - accuracy: 0.1729
# Epoch 885/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.0222e-04 - accuracy: 0.1729
# Epoch 886/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.5233e-04 - accuracy: 0.1729
# Epoch 887/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.1516e-04 - accuracy: 0.1729
# Epoch 888/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.3459e-04 - accuracy: 0.1729
# Epoch 889/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.9419e-04 - accuracy: 0.1729
# Epoch 890/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 9.6827e-04 - accuracy: 0.1728
# Epoch 891/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 9.2924e-04 - accuracy: 0.1728
# Epoch 892/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.7710e-04 - accuracy: 0.1729
# Epoch 893/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.1332e-04 - accuracy: 0.1729
# Epoch 894/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.6971e-04 - accuracy: 0.1729
# Epoch 895/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.2520e-04 - accuracy: 0.1729
# Epoch 896/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.8467e-04 - accuracy: 0.1728
# Epoch 897/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 8.3280e-04 - accuracy: 0.1728
# Epoch 898/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 6.9278e-04 - accuracy: 0.1729
# Epoch 899/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 6.7324e-04 - accuracy: 0.1729
# Epoch 900/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.7427e-04 - accuracy: 0.1729
# Epoch 901/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.1212e-04 - accuracy: 0.1729
# Epoch 902/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.8915e-04 - accuracy: 0.1729
# Epoch 903/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.9510e-04 - accuracy: 0.1729
# Epoch 904/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.1440e-04 - accuracy: 0.1729
# Epoch 905/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.4271e-04 - accuracy: 0.1729
# Epoch 906/1000
# 43/43 [==============================] - 17s 394ms/step - loss: 8.3425e-04 - accuracy: 0.1729
# Epoch 907/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.8044e-04 - accuracy: 0.1729
# Epoch 908/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0010 - accuracy: 0.1729
# Epoch 909/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0010 - accuracy: 0.1729
# Epoch 910/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.6099e-04 - accuracy: 0.1729
# Epoch 911/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.2149e-04 - accuracy: 0.1729
# Epoch 912/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.7954e-04 - accuracy: 0.1729
# Epoch 913/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.8776e-04 - accuracy: 0.1729
# Epoch 914/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.4816e-04 - accuracy: 0.1729
# Epoch 915/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.7165e-04 - accuracy: 0.1729
# Epoch 916/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 9.7963e-04 - accuracy: 0.1729
# Epoch 917/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.3643e-04 - accuracy: 0.1729
# Epoch 918/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.9610e-04 - accuracy: 0.1729
# Epoch 919/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.6099e-04 - accuracy: 0.1729
# Epoch 920/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.3992e-04 - accuracy: 0.1729
# Epoch 921/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.4219e-04 - accuracy: 0.1729
# Epoch 922/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.8810e-04 - accuracy: 0.1729
# Epoch 923/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.5783e-04 - accuracy: 0.1729
# Epoch 924/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 9.2891e-04 - accuracy: 0.1729
# Epoch 925/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 0.0010 - accuracy: 0.1728
# Epoch 926/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.1776e-04 - accuracy: 0.1729
# Epoch 927/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.7825e-04 - accuracy: 0.1729
# Epoch 928/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.3216e-04 - accuracy: 0.1729
# Epoch 929/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.8028e-04 - accuracy: 0.1729
# Epoch 930/1000
# 43/43 [==============================] - 16s 380ms/step - loss: 7.3793e-04 - accuracy: 0.1729
# Epoch 931/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.5786e-04 - accuracy: 0.1729
# Epoch 932/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.3634e-04 - accuracy: 0.1729
# Epoch 933/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.2469e-04 - accuracy: 0.1729
# Epoch 934/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.4580e-04 - accuracy: 0.1729
# Epoch 935/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.1690e-04 - accuracy: 0.1729
# Epoch 936/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.5442e-04 - accuracy: 0.1729
# Epoch 937/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 8.3016e-04 - accuracy: 0.1729
# Epoch 938/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.5656e-04 - accuracy: 0.1729
# Epoch 939/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.0276e-04 - accuracy: 0.1729
# Epoch 940/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.1292e-04 - accuracy: 0.1729
# Epoch 941/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 8.6868e-04 - accuracy: 0.1729
# Epoch 942/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.5038e-04 - accuracy: 0.1729
# Epoch 943/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 6.7053e-04 - accuracy: 0.1729
# Epoch 944/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 7.5622e-04 - accuracy: 0.1729
# Epoch 945/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 9.2782e-04 - accuracy: 0.1729
# Epoch 946/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.2243e-04 - accuracy: 0.1729
# Epoch 947/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.3810e-04 - accuracy: 0.1729
# Epoch 948/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.1947e-04 - accuracy: 0.1729
# Epoch 949/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.4556e-04 - accuracy: 0.1729
# Epoch 950/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 6.9588e-04 - accuracy: 0.1729
# Epoch 951/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.2557e-04 - accuracy: 0.1729
# Epoch 952/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.4922e-04 - accuracy: 0.1729
# Epoch 953/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.0449e-04 - accuracy: 0.1729
# Epoch 954/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.4879e-04 - accuracy: 0.1729
# Epoch 955/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.3257e-04 - accuracy: 0.1729
# Epoch 956/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 8.2624e-04 - accuracy: 0.1729
# Epoch 957/1000
# 43/43 [==============================] - 16s 379ms/step - loss: 7.5869e-04 - accuracy: 0.1729
# Epoch 958/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.0340e-04 - accuracy: 0.1729
# Epoch 959/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.6717e-04 - accuracy: 0.1729
# Epoch 960/1000
# 43/43 [==============================] - 16s 374ms/step - loss: 7.3538e-04 - accuracy: 0.1729
# Epoch 961/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.4278e-04 - accuracy: 0.1729
# Epoch 962/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 6.4828e-04 - accuracy: 0.1729
# Epoch 963/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.8333e-04 - accuracy: 0.1729
# Epoch 964/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.5240e-04 - accuracy: 0.1729
# Epoch 965/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 6.8902e-04 - accuracy: 0.1729
# Epoch 966/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.7308e-04 - accuracy: 0.1729
# Epoch 967/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.2094e-04 - accuracy: 0.1729
# Epoch 968/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.3546e-04 - accuracy: 0.1729
# Epoch 969/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.6116e-04 - accuracy: 0.1729
# Epoch 970/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 9.1224e-04 - accuracy: 0.1729
# Epoch 971/1000
# 43/43 [==============================] - 16s 378ms/step - loss: 7.3029e-04 - accuracy: 0.1729
# Epoch 972/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.7565e-04 - accuracy: 0.1729
# Epoch 973/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.6754e-04 - accuracy: 0.1729
# Epoch 974/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.1961e-04 - accuracy: 0.1729
# Epoch 975/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.3858e-04 - accuracy: 0.1729
# Epoch 976/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.2000e-04 - accuracy: 0.1729
# Epoch 977/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 9.3796e-04 - accuracy: 0.1729
# Epoch 978/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 9.7416e-04 - accuracy: 0.1729
# Epoch 979/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 6.9600e-04 - accuracy: 0.1729
# Epoch 980/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.3097e-04 - accuracy: 0.1729
# Epoch 981/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.9904e-04 - accuracy: 0.1729
# Epoch 982/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.8112e-04 - accuracy: 0.1729
# Epoch 983/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.2134e-04 - accuracy: 0.1729
# Epoch 984/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.1935e-04 - accuracy: 0.1729
# Epoch 985/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 6.8406e-04 - accuracy: 0.1729
# Epoch 986/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.2659e-04 - accuracy: 0.1729
# Epoch 987/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.7894e-04 - accuracy: 0.1729
# Epoch 988/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 7.0293e-04 - accuracy: 0.1729
# Epoch 989/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 6.3571e-04 - accuracy: 0.1729
# Epoch 990/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.9815e-04 - accuracy: 0.1729
# Epoch 991/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 0.0010 - accuracy: 0.1728
# Epoch 992/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 7.9817e-04 - accuracy: 0.1729
# Epoch 993/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.7145e-04 - accuracy: 0.1729
# Epoch 994/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.5375e-04 - accuracy: 0.1729
# Epoch 995/1000
# 43/43 [==============================] - 16s 375ms/step - loss: 8.9389e-04 - accuracy: 0.1729
# Epoch 996/1000
# 43/43 [==============================] - 16s 376ms/step - loss: 8.3779e-04 - accuracy: 0.1729
# Epoch 997/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 8.3139e-04 - accuracy: 0.1729
# Epoch 998/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 6.6769e-04 - accuracy: 0.1729
# Epoch 999/1000
# 43/43 [==============================] - 16s 377ms/step - loss: 7.7419e-04 - accuracy: 0.1729
# Epoch 1000/1000
# 43/43 [==============================] - 16s 382ms/step - loss: 8.3782e-04 - accuracy: 0.1729

# %%
import pandas as pd

model.save_weights(MODEL_PATH + MODEL_NAME+'.h5', save_format='h5')

hist = pd.DataFrame(history.history)
hist_filename = MODEL_NAME + '.json'
with open(MODEL_PATH + hist_filename, 'w') as file:
    hist.to_json(file)

# %% [markdown]
# ## 5. Test

# %%
def eval(input_token):
    answer = tf.expand_dims(start_token, 0)
    for i in range(max_length):
        prediction = model(inputs=[input_token, answer], training=False)
        prediction = prediction[:, -1:, :]
        next_token = tf.cast(tf.argmax(prediction, axis=-1), dtype=tf.int32)

        if tf.equal(next_token, end_token[0]):
            break

        answer = tf.concat([answer, next_token], axis=-1)
    return tf.squeeze(answer, axis=0)

def pred(sentence):
    sentence = preprocess(sentence)
    tokenized = tf.expand_dims(start_token + tokenizer.encode(sentence) + end_token, axis=0)

    answer_token = eval(tokenized)
    answer = tokenizer.decode(
        [x for x in answer_token if x < tokenizer.vocab_size]
    )

    print(f"질문: {sentence}")
    print(f'정답(Token): {answer_token}')
    print(f'정답: {answer}')

    return answer

# %%
from nltk.translate.bleu_score import corpus_bleu
from tqdm import tqdm

Q, A = [], []
for test_q, test_a in tqdm(zip(test_Q, test_A)):
    test_q = preprocess(test_q)
    test_q = tf.expand_dims(start_token + tokenizer.encode(test_q) + end_token, axis=0)
    pred_token = [x for x in eval(test_q).numpy() if x < tokenizer.vocab_size]
    Q.append(pred_token)

    test_a = preprocess(test_a)
    A.append([tokenizer.encode(test_a)])
# Out:
# 1000it [41:29,  2.49s/it]

# %%
print('BLEU-1 :', corpus_bleu(A, Q, weights=(1, 0, 0, 0)))
print('BLEU-2 :', corpus_bleu(A, Q, weights=(0.5, 0.5, 0, 0)))
print('BLEU-3 :', corpus_bleu(A, Q, weights=(0.33, 0.33, 0.33, 0)))
print('BLEU-4 :', corpus_bleu(A, Q, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# BLEU-1 : 0.008939462117329095
# BLEU-2 : 0.0036108485651868876
# BLEU-3 : 0.0019243356049317322
# BLEU-4 : 0.0011447194277632124

# %%
pred('영화')
# Out:
# 질문: 영화 볼래 ?
# 정답(Token): [8178 6072 1089   27   75   18   22    1]
# 정답: 최신 영화가 좋을 것 같아요 .
# '최신 영화가 좋을 것 같아요 .'

# %%
pred('밥')
# Out:
# 질문: 밥 먹고 싶어
# 정답(Token): [8178  842    8  126    1]
# 정답: 맛있는 거 드세요 .
# '맛있는 거 드세요 .'

# %%
pred('곧')
# Out:
# 질문: 곧 연말이야
# 정답(Token): [8178 1202  213    1]
# 정답: 혼자가 아니에요 .
# '혼자가 아니에요 .'
