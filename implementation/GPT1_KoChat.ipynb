# %% [markdown]
# <a href="https://colab.research.google.com/github/sonhs99/NLP/blob/main/implementation/GPT1_KoChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT - 1 모델 구현 - Pretrain
#
# 사용 데이터: 인공적으로 제작된 문답 쌍 11,876개 (https://github.com/songys/Chatbot_data)

# %%
from google.colab import drive
drive.mount('/content/drive')

MODEL_PATH = 'drive/MyDrive/weights/GPT1/'
PREV_MODEL_NAME = None #'koGPTv3'
MODEL_NAME = 'koGPTv5'
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
import urllib.request
import pandas as pd

urllib.request.urlretrieve("https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv", filename="ChatBotData.csv")
train_data = pd.read_csv('ChatBotData.csv')
train_data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %% [markdown]
# ## 1. 데이터 정제 및 사전 구축

# %%
import re

# 데이터 정제
# 문장부호를 단어로부터 분리

def preprocess(sentence):
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    return sentence

questions = []
for sentence in train_data['Q']:
    questions.append(preprocess(sentence))

answers = []
for sentence in train_data['A']:
    answers.append(preprocess(sentence))

print(questions[:5])
print(answers[:5])

train_Q, train_A = questions[:-1000], answers[:-1000]
test_Q, test_A = questions[-1000:], answers[-1000:]
# Out:
# ['12시 땡 !', '1지망 학교 떨어졌어', '3박4일 놀러가고 싶다', '3박4일 정도 놀러가고 싶다', 'PPL 심하네']
# ['하루가 또 가네요 .', '위로해 드립니다 .', '여행은 언제나 좋죠 .', '여행은 언제나 좋죠 .', '눈살이 찌푸려지죠 .']

# %%
import tensorflow_datasets as tfds

# Tokenizer 선언
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13
)

# 사전 크기 조정
# 문자열에 대한 사전 크기에 시작, 종결 토큰 추가
start_token, end_token, delimiter_token = [tokenizer.vocab_size], [tokenizer.vocab_size + 1], [tokenizer.vocab_size + 2]
vocab_size = tokenizer.vocab_size + 3

print('시작 토큰 :', start_token)
print('종결 토큰 :', end_token)
print('사전 크기 :', vocab_size)
# Out:
# 시작 토큰 : [8178]
# 종결 토큰 : [8179]
# 사전 크기 : 8181

# %%
print('원본 :', questions[20])
tokenized_string = tokenizer.encode(questions[20])
print('부호화 문자열 :', tokenized_string)
print('복호화 :', tokenizer.decode(tokenized_string))
# Out:
# 원본 : 가스비 비싼데 감기 걸리겠어
# 부호화 문자열 : [5766, 611, 3509, 141, 685, 3747, 849]
# 복호화 : 가스비 비싼데 감기 걸리겠어

# %%
max_length = 40

def tokenize_and_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []

    for s1, s2 in zip(inputs, outputs):
        s1 = start_token + tokenizer.encode(s1) + end_token
        s2 = start_token + tokenizer.encode(s2) + end_token

        tokenized_inputs.append(s1)
        tokenized_outputs.append(s2)

    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_inputs, maxlen=max_length+1, padding='post'
    )
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_outputs, maxlen=max_length+1, padding='post'
    )

    return tokenized_inputs, tokenized_outputs

train_Q, train_A = tokenize_and_filter(train_Q, train_A)
print(train_Q.shape, train_A.shape)
# Out:
# (10823, 41) (10823, 41)

# %%
batch_size = 256
buffer_size = 20000

def create_dataset(questions, answers):
    data = tf.concat([questions, answers], axis=0)
    dataset = tf.data.Dataset.from_tensor_slices((
        {
            'input': data[:, :-1] # 종결 토큰 제거, 1문장 40단어
        },
        {
            'output': data[:, 1:], # 시작 토큰 제거, 1문장 40단어
        }
    ))

    dataset = dataset.cache()
    dataset = dataset.shuffle(buffer_size)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

train_dataset = create_dataset(train_Q, train_A)

# %% [markdown]
# ## 2. Custom Layer 선언

# %%
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, dim):
        super(PositionalEncoding, self).__init__()
        self.sequence_length = sequence_length
        self.pos_vec = tf.keras.layers.Embedding(sequence_length, dim)

    def call(self, x):
        vec = tf.range(self.sequence_length)
        return x + self.pos_vec(vec)[:tf.shape(x)[1]]

# %%
def attention(query, key, value, mask):
    depth = tf.cast(tf.shape(key)[-1], dtype=tf.float32)
    logit = tf.matmul(query, key, transpose_b=True) / tf.math.sqrt(depth)

    if mask is not None:
        logit += (mask * -1e9)

    dist = tf.nn.softmax(logit, axis=-1)
    return tf.matmul(dist, value)

class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, num_head, dim):
        super(AttentionLayer, self).__init__()

        assert dim % num_head == 0

        self.query = tf.keras.layers.Dense(dim, use_bias=False)
        self.key = tf.keras.layers.Dense(dim, use_bias=False)
        self.value = tf.keras.layers.Dense(dim, use_bias=False)

        self.w_o = tf.keras.layers.Dense(dim, use_bias=False)

        self.num_head = num_head
        self.dim = dim
        self.head_size = dim // num_head

    def split_value(self, x, batch_size):
        split = tf.reshape(x, [batch_size, -1, self.num_head, self.head_size])  # [batch, num_vocab, num_head, head_dim]
        return tf.transpose(split, [0, 2, 1, 3])                                # [batch, num_head, num_vocab, head_dim]

    def call(self, inputs):
        query = self.query(inputs[0])
        key = self.key(inputs[1])
        value = self.value(inputs[2])
        mask = inputs[3]

        batch_size = tf.shape(query)[0]

        query = self.split_value(query, batch_size)
        key = self.split_value(key, batch_size)
        value = self.split_value(value, batch_size)

        attention_value = attention(query, key, value, mask)                # [batch, num_head, num_vocab, head_dim]
        attention_value = tf.transpose(attention_value, perm=[0, 2, 1, 3])  # [batch, num_vocab, num_head, head_dim]
        attention_value = tf.reshape(attention_value, [batch_size, -1, self.dim]) # [batch, num_vocab, d_model] (num_head * head_dim = d_model)
        return self.w_o(attention_value)

# %%
class EmbeddingTransposeLayer(tf.keras.layers.Layer):
    def __init__(self, embedding_layer: tf.keras.layers.Embedding, **kargs):
        super(EmbeddingTransposeLayer, self).__init__(**kargs)
        self.embeddings = embedding_layer

    def build(self, input_shape):
        self.custom_weights = self.embeddings.weights[0]
        self.build = True

    def compute_output_shape(self, input_shape):
        return input_shape[0], tf.keras.backend.int_shape(self.custom_weights)[0]

    def call(self, x):
        return tf.keras.backend.dot(
            x, tf.keras.backend.transpose(self.custom_weights))

# %% [markdown]
# ## 3. Decoder 블록 및 GPT 모델 생성

# %%
def decoder_block(dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None, dim])
    mask_input = tf.keras.layers.Input([1, None, None])

    mask_attention_x = AttentionLayer(num_head, dim)([input, input, input, mask_input])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(input + mask_attention_x)

    ffnn_x = tf.keras.layers.Dense(dif, activation='gelu')(x)
    ffnn_x = tf.keras.layers.Dense(dim)(ffnn_x)

    ffnn_x = tf.keras.layers.Dropout(dropout)(ffnn_x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x + ffnn_x)
    return tf.keras.Model(inputs=[input, mask_input], outputs=x)

def decoder(vocab_size, num_layers, dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None, dim])
    mask_input = tf.keras.layers.Input([1, None, None])

    positional_encoding = PositionalEncoding(max_length * 2 + 3, dim)(input)
    output = tf.keras.layers.Dropout(dropout)(positional_encoding)

    for i in range(num_layers):
        output = decoder_block(dif, num_head, dim, dropout)([output, mask_input])

    return tf.keras.Model(inputs=[input, mask_input], outputs=output, name='decoder')

# %%
def padding_mask(x):
    mask = tf.cast(tf.math.equal(x, 0), dtype=tf.float32)
    return mask[:, tf.newaxis, tf.newaxis, :]

def look_ahead_mask(x):
    seq_len = tf.shape(x)[1]
    t_look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
    t_padding_mask = padding_mask(x)
    return tf.maximum(t_look_ahead_mask, t_padding_mask)

def gpt_model(vocab_size, num_layers, dif, num_head, dim, dropout):
    input = tf.keras.layers.Input([None,], name='input')

    embedding_layer = tf.keras.layers.Embedding(vocab_size, dim)
    embedding = embedding_layer(input)
    dec_mask = tf.keras.layers.Lambda(look_ahead_mask, output_shape=[1, None, None])(input)

    dec = decoder(vocab_size, num_layers, dif, num_head, dim, dropout)([embedding, dec_mask])

    output = EmbeddingTransposeLayer(embedding_layer, name='output')(dec)
    return tf.keras.Model(inputs=input, outputs=output)

# %%
dim = 768
num_layers = 12
num_head = 12
diff = 3072
dropout = 0.1

model = gpt_model(
    vocab_size=vocab_size,
    num_layers=num_layers,
    dif=diff,
    dim=dim,
    num_head=num_head,
    dropout=dropout
)

if PREV_MODEL_NAME: model.load_weights(MODEL_PATH+PREV_MODEL_NAME+'.h5')

# %% [markdown]
# ## 4. 모델 Compile 및 학습

# %%
class TransformerSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, dim, warmup_step=4000):
        self.d_model = tf.cast(dim, tf.float32)
        self.warmup_step = warmup_step

    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        temp1 = tf.math.rsqrt(step)
        temp2 = step * (self.warmup_step ** -1.5)

        return tf.math.rsqrt(self.d_model) * tf.math.minimum(temp1, temp2)

    def get_config(self):
        config = {
            'dim': self.d_model,
            'warmup_step': self.warmup_step,
        }
        return config

# %%
# lr = tf.keras.optimizers.schedules.CosineDecay(
#     initial_learning_rate=0,
#     decay_steps=2000,
#     warmup_target=2.5e-4,
#     warmup_steps=2000
# )
lr = TransformerSchedule(dim)
opt = tf.optimizers.Adam(learning_rate=lr, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, max_length))
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

def perplexity(y_true, y_pred):
    loss = loss_function(y_true, y_pred)
    return tf.math.exp(loss)

def loss_function(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, max_length))
    loss = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True, reduction='none'
    )(y_true, y_pred)
    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
    loss = tf.multiply(loss, mask)
    return tf.reduce_mean(loss)

model.compile(
    optimizer=opt, loss=loss_function, metrics=[accuracy, perplexity])

# %%
model.summary(expand_nested=True)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, None)]               0         []
#
#  embedding (Embedding)       (None, None, 768)            6283008   ['input[0][0]']
#
#  lambda (Lambda)             (None, 1, None, None)        0         ['input[0][0]']
#
#  decoder (Functional)        (None, None, 768)            8508134   ['embedding[0][0]',
#                                                           4          'lambda[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)       [(None, None, 768)]          0         []                           |
# |                                                                                                |
# | positional_encoding (Posi  (None, None, 768)            63744     []                           |
# | tionalEncoding)                                                                                |
# |                                                                                                |
# | dropout (Dropout)          (None, None, 768)            0         []                           |
# |                                                                                                |
# | input_2 (InputLayer)       [(None, 1, None, None)]      0         []                           |
# |                                                                                                |
# | model (Functional)         (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_3 (InputLayer)      [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_4 (InputLayer)      [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer (Attenti  (None, None, 768)            2359296   []                          ||
# || onLayer)                                                                                     ||
# ||                                                                                              ||
# || tf.__operators__.add (TF  (None, None, 768)            0         []                          ||
# || OpLambda)                                                                                    ||
# ||                                                                                              ||
# || layer_normalization (Lay  (None, None, 768)            1536      []                          ||
# || erNormalization)                                                                             ||
# ||                                                                                              ||
# || dense_4 (Dense)           (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_5 (Dense)           (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_1 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_1 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_1 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_1 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_5 (InputLayer)      [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_6 (InputLayer)      [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_1 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_2 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_2 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_10 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_11 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_2 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_3 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_3 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_2 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_7 (InputLayer)      [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_8 (InputLayer)      [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_2 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_4 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_4 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_16 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_17 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_3 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_5 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_5 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_3 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_9 (InputLayer)      [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_10 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_3 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_6 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_6 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_22 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_23 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_4 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_7 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_7 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_4 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_11 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_12 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_4 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_8 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_8 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# ||                                                                                              ||
# || dense_28 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_29 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_5 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_9 (  (None, None, 768)            0         []                          ||
# || TFOpLambda)                                                                                  ||
# ||                                                                                              ||
# || layer_normalization_9 (L  (None, None, 768)            1536      []                          ||
# || ayerNormalization)                                                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_5 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_13 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_14 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_5 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_10   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_10 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_34 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_35 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_6 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_11   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_11 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_6 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_15 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_16 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_6 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_12   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_12 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_40 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_41 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_7 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_13   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_13 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_7 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_17 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_18 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_7 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_14   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_14 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_46 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_47 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_8 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_15   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_15 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_8 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_19 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_20 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_8 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_16   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_16 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_52 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_53 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_9 (Dropout)       (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_17   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_17 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_9 (Functional)       (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_21 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_22 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_9 (Atten  (None, None, 768)            2359296   []                          ||
# || tionLayer)                                                                                   ||
# ||                                                                                              ||
# || tf.__operators__.add_18   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_18 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_58 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_59 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_10 (Dropout)      (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_19   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_19 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_10 (Functional)      (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_23 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_24 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_10 (Atte  (None, None, 768)            2359296   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_20   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_20 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_64 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_65 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_11 (Dropout)      (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_21   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_21 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | model_11 (Functional)      (None, None, 768)            7084800   []                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_25 (InputLayer)     [(None, None, 768)]          0         []                          ||
# ||                                                                                              ||
# || input_26 (InputLayer)     [(None, 1, None, None)]      0         []                          ||
# ||                                                                                              ||
# || attention_layer_11 (Atte  (None, None, 768)            2359296   []                          ||
# || ntionLayer)                                                                                  ||
# ||                                                                                              ||
# || tf.__operators__.add_22   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_22 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# ||                                                                                              ||
# || dense_70 (Dense)          (None, None, 3072)           2362368   []                          ||
# ||                                                                                              ||
# || dense_71 (Dense)          (None, None, 768)            2360064   []                          ||
# ||                                                                                              ||
# || dropout_12 (Dropout)      (None, None, 768)            0         []                          ||
# ||                                                                                              ||
# || tf.__operators__.add_23   (None, None, 768)            0         []                          ||
# || (TFOpLambda)                                                                                 ||
# ||                                                                                              ||
# || layer_normalization_23 (  (None, None, 768)            1536      []                          ||
# || LayerNormalization)                                                                          ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  output (EmbeddingTranspose  (None, None, 8181)           6283008   ['decoder[0][0]']
#  Layer)
#
# ==================================================================================================
# Total params: 91364352 (348.53 MB)
# Trainable params: 91364352 (348.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
epoch = 400
history = model.fit(train_dataset, epochs=epoch, callbacks=[
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, start_from_epoch=100)
])
# Out:
# Epoch 1/400
# 85/85 [==============================] - 93s 606ms/step - loss: 1.2739 - accuracy: 0.0210 - perplexity: 3.5889
# Epoch 2/400
# 85/85 [==============================] - 51s 605ms/step - loss: 1.1352 - accuracy: 0.0274 - perplexity: 3.1134
# Epoch 3/400
# 85/85 [==============================] - 52s 607ms/step - loss: 1.0741 - accuracy: 0.0305 - perplexity: 2.9300
# Epoch 4/400
# 85/85 [==============================] - 52s 606ms/step - loss: 1.0346 - accuracy: 0.0330 - perplexity: 2.8170
# Epoch 5/400
# 85/85 [==============================] - 51s 605ms/step - loss: 1.0029 - accuracy: 0.0361 - perplexity: 2.7274
# Epoch 6/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.9726 - accuracy: 0.0389 - perplexity: 2.6454
# Epoch 7/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.9408 - accuracy: 0.0412 - perplexity: 2.5635
# Epoch 8/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.9045 - accuracy: 0.0437 - perplexity: 2.4716
# Epoch 9/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.8659 - accuracy: 0.0462 - perplexity: 2.3781
# Epoch 10/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.8266 - accuracy: 0.0492 - perplexity: 2.2862
# Epoch 11/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.7872 - accuracy: 0.0523 - perplexity: 2.1980
# Epoch 12/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.7479 - accuracy: 0.0560 - perplexity: 2.1137
# Epoch 13/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.7072 - accuracy: 0.0599 - perplexity: 2.0287
# Epoch 14/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.6654 - accuracy: 0.0643 - perplexity: 1.9459
# Epoch 15/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.6249 - accuracy: 0.0690 - perplexity: 1.8687
# Epoch 16/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.5847 - accuracy: 0.0740 - perplexity: 1.7953
# Epoch 17/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.5462 - accuracy: 0.0787 - perplexity: 1.7275
# Epoch 18/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.5082 - accuracy: 0.0838 - perplexity: 1.6625
# Epoch 19/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.4733 - accuracy: 0.0886 - perplexity: 1.6061
# Epoch 20/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.4432 - accuracy: 0.0926 - perplexity: 1.5578
# Epoch 21/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.4161 - accuracy: 0.0967 - perplexity: 1.5164
# Epoch 22/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.3934 - accuracy: 0.0999 - perplexity: 1.4822
# Epoch 23/400
# 85/85 [==============================] - 52s 610ms/step - loss: 0.3749 - accuracy: 0.1031 - perplexity: 1.4551
# Epoch 24/400
# 85/85 [==============================] - 52s 609ms/step - loss: 0.3599 - accuracy: 0.1053 - perplexity: 1.4335
# Epoch 25/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.3491 - accuracy: 0.1069 - perplexity: 1.4179
# Epoch 26/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3403 - accuracy: 0.1083 - perplexity: 1.4057
# Epoch 27/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3361 - accuracy: 0.1087 - perplexity: 1.3998
# Epoch 28/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.3316 - accuracy: 0.1092 - perplexity: 1.3934
# Epoch 29/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3293 - accuracy: 0.1095 - perplexity: 1.3903
# Epoch 30/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3276 - accuracy: 0.1096 - perplexity: 1.3878
# Epoch 31/400
# 85/85 [==============================] - 52s 608ms/step - loss: 0.3265 - accuracy: 0.1094 - perplexity: 1.3865
# Epoch 32/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3259 - accuracy: 0.1093 - perplexity: 1.3855
# Epoch 33/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3256 - accuracy: 0.1094 - perplexity: 1.3851
# Epoch 34/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3249 - accuracy: 0.1092 - perplexity: 1.3841
# Epoch 35/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3252 - accuracy: 0.1090 - perplexity: 1.3845
# Epoch 36/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.3406 - accuracy: 0.1060 - perplexity: 1.4066
# Epoch 37/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3173 - accuracy: 0.1103 - perplexity: 1.3736
# Epoch 38/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.3229 - accuracy: 0.1092 - perplexity: 1.3814
# Epoch 39/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3275 - accuracy: 0.1080 - perplexity: 1.3878
# Epoch 40/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3296 - accuracy: 0.1074 - perplexity: 1.3906
# Epoch 41/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3275 - accuracy: 0.1078 - perplexity: 1.3879
# Epoch 42/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.3294 - accuracy: 0.1072 - perplexity: 1.3904
# Epoch 43/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3299 - accuracy: 0.1071 - perplexity: 1.3912
# Epoch 44/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3304 - accuracy: 0.1067 - perplexity: 1.3917
# Epoch 45/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3303 - accuracy: 0.1070 - perplexity: 1.3917
# Epoch 46/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3316 - accuracy: 0.1065 - perplexity: 1.3934
# Epoch 47/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3333 - accuracy: 0.1061 - perplexity: 1.3957
# Epoch 48/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3350 - accuracy: 0.1059 - perplexity: 1.3985
# Epoch 49/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3308 - accuracy: 0.1061 - perplexity: 1.3921
# Epoch 50/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3247 - accuracy: 0.1077 - perplexity: 1.3839
# Epoch 51/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3244 - accuracy: 0.1076 - perplexity: 1.3834
# Epoch 52/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3220 - accuracy: 0.1080 - perplexity: 1.3802
# Epoch 53/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.3209 - accuracy: 0.1080 - perplexity: 1.3785
# Epoch 54/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3182 - accuracy: 0.1084 - perplexity: 1.3748
# Epoch 55/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3159 - accuracy: 0.1088 - perplexity: 1.3718
# Epoch 56/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3139 - accuracy: 0.1093 - perplexity: 1.3689
# Epoch 57/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3115 - accuracy: 0.1097 - perplexity: 1.3658
# Epoch 58/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3105 - accuracy: 0.1097 - perplexity: 1.3642
# Epoch 59/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3089 - accuracy: 0.1100 - perplexity: 1.3620
# Epoch 60/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.3072 - accuracy: 0.1103 - perplexity: 1.3598
# Epoch 61/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3057 - accuracy: 0.1105 - perplexity: 1.3577
# Epoch 62/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3039 - accuracy: 0.1107 - perplexity: 1.3554
# Epoch 63/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.3032 - accuracy: 0.1109 - perplexity: 1.3543
# Epoch 64/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.3014 - accuracy: 0.1109 - perplexity: 1.3518
# Epoch 65/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.3000 - accuracy: 0.1113 - perplexity: 1.3501
# Epoch 66/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2980 - accuracy: 0.1115 - perplexity: 1.3473
# Epoch 67/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2972 - accuracy: 0.1117 - perplexity: 1.3463
# Epoch 68/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2962 - accuracy: 0.1119 - perplexity: 1.3448
# Epoch 69/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2945 - accuracy: 0.1120 - perplexity: 1.3426
# Epoch 70/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2943 - accuracy: 0.1119 - perplexity: 1.3423
# Epoch 71/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2937 - accuracy: 0.1120 - perplexity: 1.3414
# Epoch 72/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2923 - accuracy: 0.1122 - perplexity: 1.3396
# Epoch 73/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2914 - accuracy: 0.1123 - perplexity: 1.3384
# Epoch 74/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2906 - accuracy: 0.1125 - perplexity: 1.3373
# Epoch 75/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2891 - accuracy: 0.1127 - perplexity: 1.3353
# Epoch 76/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2889 - accuracy: 0.1126 - perplexity: 1.3351
# Epoch 77/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2892 - accuracy: 0.1124 - perplexity: 1.3355
# Epoch 78/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2862 - accuracy: 0.1131 - perplexity: 1.3315
# Epoch 79/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2862 - accuracy: 0.1129 - perplexity: 1.3315
# Epoch 80/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2858 - accuracy: 0.1130 - perplexity: 1.3310
# Epoch 81/400
# 85/85 [==============================] - 53s 621ms/step - loss: 0.2853 - accuracy: 0.1131 - perplexity: 1.3303
# Epoch 82/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2844 - accuracy: 0.1132 - perplexity: 1.3290
# Epoch 83/400
# 85/85 [==============================] - 52s 609ms/step - loss: 0.2837 - accuracy: 0.1132 - perplexity: 1.3281
# Epoch 84/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2828 - accuracy: 0.1133 - perplexity: 1.3269
# Epoch 85/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2824 - accuracy: 0.1134 - perplexity: 1.3264
# Epoch 86/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2821 - accuracy: 0.1134 - perplexity: 1.3260
# Epoch 87/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.2810 - accuracy: 0.1135 - perplexity: 1.3246
# Epoch 88/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.2818 - accuracy: 0.1133 - perplexity: 1.3256
# Epoch 89/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2797 - accuracy: 0.1139 - perplexity: 1.3228
# Epoch 90/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2794 - accuracy: 0.1138 - perplexity: 1.3224
# Epoch 91/400
# 85/85 [==============================] - 51s 606ms/step - loss: 0.2790 - accuracy: 0.1138 - perplexity: 1.3220
# Epoch 92/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2790 - accuracy: 0.1137 - perplexity: 1.3218
# Epoch 93/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2784 - accuracy: 0.1139 - perplexity: 1.3211
# Epoch 94/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2777 - accuracy: 0.1139 - perplexity: 1.3202
# Epoch 95/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2777 - accuracy: 0.1139 - perplexity: 1.3202
# Epoch 96/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2764 - accuracy: 0.1141 - perplexity: 1.3184
# Epoch 97/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2762 - accuracy: 0.1141 - perplexity: 1.3182
# Epoch 98/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2763 - accuracy: 0.1141 - perplexity: 1.3183
# Epoch 99/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2758 - accuracy: 0.1142 - perplexity: 1.3178
# Epoch 100/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2759 - accuracy: 0.1141 - perplexity: 1.3178
# Epoch 101/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2750 - accuracy: 0.1142 - perplexity: 1.3167
# Epoch 102/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2749 - accuracy: 0.1140 - perplexity: 1.3164
# Epoch 103/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2741 - accuracy: 0.1142 - perplexity: 1.3154
# Epoch 104/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2736 - accuracy: 0.1143 - perplexity: 1.3148
# Epoch 105/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2740 - accuracy: 0.1142 - perplexity: 1.3153
# Epoch 106/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2730 - accuracy: 0.1145 - perplexity: 1.3140
# Epoch 107/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2730 - accuracy: 0.1144 - perplexity: 1.3140
# Epoch 108/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2731 - accuracy: 0.1143 - perplexity: 1.3141
# Epoch 109/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2726 - accuracy: 0.1144 - perplexity: 1.3135
# Epoch 110/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2722 - accuracy: 0.1143 - perplexity: 1.3130
# Epoch 111/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2717 - accuracy: 0.1145 - perplexity: 1.3123
# Epoch 112/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2718 - accuracy: 0.1145 - perplexity: 1.3124
# Epoch 113/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2712 - accuracy: 0.1146 - perplexity: 1.3116
# Epoch 114/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2707 - accuracy: 0.1147 - perplexity: 1.3110
# Epoch 115/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2707 - accuracy: 0.1146 - perplexity: 1.3110
# Epoch 116/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2708 - accuracy: 0.1146 - perplexity: 1.3111
# Epoch 117/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2755 - accuracy: 0.1139 - perplexity: 1.3174
# Epoch 118/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2711 - accuracy: 0.1145 - perplexity: 1.3115
# Epoch 119/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2694 - accuracy: 0.1149 - perplexity: 1.3093
# Epoch 120/400
# 85/85 [==============================] - 52s 609ms/step - loss: 0.2699 - accuracy: 0.1146 - perplexity: 1.3099
# Epoch 121/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2695 - accuracy: 0.1147 - perplexity: 1.3094
# Epoch 122/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2691 - accuracy: 0.1147 - perplexity: 1.3089
# Epoch 123/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2692 - accuracy: 0.1146 - perplexity: 1.3090
# Epoch 124/400
# 85/85 [==============================] - 52s 608ms/step - loss: 0.2688 - accuracy: 0.1148 - perplexity: 1.3085
# Epoch 125/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2686 - accuracy: 0.1149 - perplexity: 1.3082
# Epoch 126/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2684 - accuracy: 0.1149 - perplexity: 1.3080
# Epoch 127/400
# 85/85 [==============================] - 52s 607ms/step - loss: 0.2685 - accuracy: 0.1147 - perplexity: 1.3080
# Epoch 128/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2679 - accuracy: 0.1149 - perplexity: 1.3074
# Epoch 129/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2711 - accuracy: 0.1146 - perplexity: 1.3117
# Epoch 130/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2674 - accuracy: 0.1150 - perplexity: 1.3066
# Epoch 131/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2680 - accuracy: 0.1149 - perplexity: 1.3074
# Epoch 132/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2671 - accuracy: 0.1150 - perplexity: 1.3062
# Epoch 133/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2670 - accuracy: 0.1150 - perplexity: 1.3061
# Epoch 134/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2675 - accuracy: 0.1149 - perplexity: 1.3067
# Epoch 135/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2668 - accuracy: 0.1150 - perplexity: 1.3059
# Epoch 136/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2670 - accuracy: 0.1149 - perplexity: 1.3061
# Epoch 137/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2665 - accuracy: 0.1152 - perplexity: 1.3055
# Epoch 138/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2660 - accuracy: 0.1151 - perplexity: 1.3049
# Epoch 139/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2674 - accuracy: 0.1148 - perplexity: 1.3066
# Epoch 140/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2653 - accuracy: 0.1152 - perplexity: 1.3039
# Epoch 141/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2653 - accuracy: 0.1152 - perplexity: 1.3040
# Epoch 142/400
# 85/85 [==============================] - 52s 606ms/step - loss: 0.2656 - accuracy: 0.1152 - perplexity: 1.3042
# Epoch 143/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2659 - accuracy: 0.1150 - perplexity: 1.3047
# Epoch 144/400
# 85/85 [==============================] - 51s 604ms/step - loss: 0.2661 - accuracy: 0.1150 - perplexity: 1.3050
# Epoch 145/400
# 85/85 [==============================] - 51s 605ms/step - loss: 0.2653 - accuracy: 0.1152 - perplexity: 1.3040

# %%
import pandas as pd

model.save_weights(MODEL_PATH + MODEL_NAME+'.h5', save_format='h5')

hist = pd.DataFrame(history.history)
hist_filename = MODEL_NAME + '.json'
with open(MODEL_PATH + hist_filename, 'w') as file:
    hist.to_json(file)

# %% [markdown]
# ## 5. Test

# %%
def eval(tokens):
    answer = tf.expand_dims(start_token + tokens, 0)
    for i in range(max_length):
        prediction = model(inputs=answer, training=False)
        prediction = prediction[:, -1:, :]
        next_token = tf.cast(tf.argmax(prediction, axis=-1), dtype=tf.int32)

        if tf.equal(next_token, end_token[0]):
            break

        answer = tf.concat([answer, next_token], axis=-1)
    return tf.squeeze(answer, axis=0)

def pred(sentence):
    sentence = preprocess(sentence)
    tokenized = tokenizer.encode(sentence)

    answer_token = eval(tokenized)
    answer = tokenizer.decode(
        [x for x in answer_token if x < tokenizer.vocab_size]
    )

    print(f"단어: {sentence}")
    print(f'생성(Token): {answer_token}')
    print(f'생성: {answer}')

    return answer

# %%
pred('라면')
# Out:
# 단어: 라면
# 생성(Token): [8178 4423 8157 8102 8059   31 7356 7954 2380   32    1]
# 생성: 라면봉지 레시피 그대로 해보세요 .
# '라면봉지 레시피 그대로 해보세요 .'

# %%
pred('밥')
# Out:
# 단어: 밥
# 생성(Token): [8178 1330 4192  456  505    1]
# 생성: 밥심으로 사는 거죠 .
# '밥심으로 사는 거죠 .'

# %%
pred('땅')
# Out:
# 단어: 땅
# 생성(Token): [8178 2662  657 1322]
# 생성: 땅이나 살까
# '땅이나 살까'
